# %%
# imports
import numpy as np
import matplotlib.pyplot as plt

# %%
# data
m = 100
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %%
# train poly data
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly_features.fit_transform(X)
print(X[0])
print(X_poly[0])
# Out:
# [0.46424496]
# [0.46424496 0.21552338]

# %%
# predict poly data
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([2.12363549]), array([[1.00560088, 0.43811536]]))

# %%
# plot data
plt.plot(X,y, ".")
X_pred = np.linspace(-3,3,100)
y_pred = lin_reg.coef_[0][1]*X_pred**2 + lin_reg.coef_[0][0]*X_pred + lin_reg.intercept_
plt.plot(X_pred, y_pred, "r", label="Predictions", zorder=0)
plt.xlabel("$x_1$")
plt.ylabel("$y$")
plt.legend()
plt.show()
